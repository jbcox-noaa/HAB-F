# %%
# %run cnn_labeler.py
# Out:
# QUEUEING TASKS | :   0%|          | 0/2 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/2 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:No valid data for this wavelength slice in bbox region
# WARNING:root:Regrid PACE slice failed.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...
# Output()
